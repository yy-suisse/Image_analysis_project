# %%
import os, sys
import lib, find_suite
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # extract suite model
# 1. load template model
# 2. connected component
# 3. take labels of location [60,60]
# 4. calculate max min to scale

# %%
from skimage.measure import label
from skimage.filters import threshold_otsu
from skimage.color import rgb2gray
from skimage import data
import cv2 
from skimage.feature import match_template

# %%
def show_suites_for_all_players(file):
    
    image = lib.read_image(file)
    image_dealer = lib.mask_dealer(image)
    extracted = lib.mask_for_extract_cards(image_dealer)
    players,centers,points_f,labels = lib.players_clustering(extracted)
    cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)

    for i in range(4):
        plt.subplot(1,4,i+1)
        plt.imshow(cards[i])
        plt.title('player '+ str(i+1) )
    plt.show()

    for i in range(4):
        cropped_suite,xmin,xmax,ymin,ymax = find_suite.crop_suite(cards[i])
        color = find_suite.detect_color(xmin,xmax,ymin,ymax,cards[i])
        res = find_suite.affin_transform_suites(cropped_suite,xmin,xmax,ymin,ymax) # affin transform with h=63, w=46
        bin_res = find_suite.binary_transform(res)

        best_score = 0.0
        best_index = None
        for j in range(4):
            result = match_template(bin_res, template_dict[suite_tab[j]])
            result = abs(result)

            if result > best_score:
                best_score = result
                best_index = j
        print("player: ", i+1)
        print("matching suite: ", suite_tab[best_index])
        #plt.imshow(bin_res)
    #plt.show()

# %%
# 1. load templates:
template_dict={}
template_list = lib.walkFile('templates')
for file in template_list:
    if 'club' in file:
        template_dict['club'] = find_suite.binary_transform(lib.read_image(file))
    if 'diamond' in file:
        template_dict['diamond'] = find_suite.binary_transform(lib.read_image(file))
    if 'heart' in file:
        template_dict['heart'] = find_suite.binary_transform(lib.read_image(file))
    if 'spade' in file:
        template_dict['spade'] = find_suite.binary_transform(lib.read_image(file))

        
suite_tab = ['diamond','heart','club','spade']     
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(template_dict[suite_tab[i]])
plt.show()

# %%
# test 1
file = "../train_games/game5/2.jpg"
image = lib.read_image(file)
image_dealer = lib.mask_dealer(image)
extracted = lib.mask_for_extract_cards(image_dealer)
players,centers,points_f,labels = lib.players_clustering(extracted)
cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(cards[i])
    plt.title('player '+ str(i+1) )
plt.show()

for i in range(4):
    cropped_suite,xmin,xmax,ymin,ymax = find_suite.crop_suite(cards[i])
    color = find_suite.detect_color(xmin,xmax,ymin,ymax,cards[i])
    res = find_suite.affin_transform_suites(cropped_suite,xmin,xmax,ymin,ymax) # affin transform with h=63, w=46
    bin_res = find_suite.binary_transform(res)
    
    best_score = 0.0
    best_index = None
    for j in range(4):
        result = match_template(bin_res, template_dict[suite_tab[j]])
        if result > best_score:
            best_score = result
            best_index = j
    print("player: ", i+1)
    print("matching suite: ", suite_tab[best_index])
    plt.imshow(bin_res)
plt.show()
# Out:
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  heart

# %%
# test 2
file = "../train_games/game4/6.jpg"
image = lib.read_image(file)
image_dealer = lib.mask_dealer(image)
extracted = lib.mask_for_extract_cards(image_dealer)
players,centers,points_f,labels = lib.players_clustering(extracted)
cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(cards[i])
    plt.title('player '+ str(i+1) )
plt.show()


for i in range(4):
    cropped_suite,xmin,xmax,ymin,ymax = find_suite.crop_suite(cards[i])
    color = find_suite.detect_color(xmin,xmax,ymin,ymax,cards[i])
    res = find_suite.affin_transform_suites(cropped_suite,xmin,xmax,ymin,ymax) # affin transform with h=63, w=46
    bin_res = find_suite.binary_transform(res)
    
    

    best_score = 0.0
    best_index = None
    for j in range(4):
        result = match_template(bin_res, template_dict[suite_tab[j]])
        if result > best_score:
            best_score = result
            best_index = j
    print("player: ", i+1)
    print("matching suite: ", suite_tab[best_index])
    plt.imshow(bin_res)
plt.show()
# Out:
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  spade

# %%
file = "../train_games/game6/4.jpg"
image = lib.read_image(file)
image_dealer = lib.mask_dealer(image)
extracted = lib.mask_for_extract_cards(image_dealer)
players,centers,points_f,labels = lib.players_clustering(extracted)
cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)

for i in range(4):
    plt.subplot(1,4,i+1)
    plt.imshow(cards[i])
    plt.title('player '+ str(i+1) )
plt.show()

for i in range(4):
    cropped_suite,xmin,xmax,ymin,ymax = find_suite.crop_suite(cards[i])
    color = find_suite.detect_color(xmin,xmax,ymin,ymax,cards[i])
    res = find_suite.affin_transform_suites(cropped_suite,xmin,xmax,ymin,ymax) # affin transform with h=63, w=46
    bin_res = find_suite.binary_transform(res)
    
    best_score = 0.0
    best_index = None
    for j in range(4):
        result = match_template(bin_res, template_dict[suite_tab[j]])
        result = abs(result)
        print(result)
        if result > best_score:
            best_score = result
            best_index = j
    print("player: ", i+1)
    print("matching suite: ", suite_tab[best_index])
    plt.imshow(bin_res)
plt.show()
# Out:
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-21-7e41183ee6ff> in <module>
#       4 extracted = lib.mask_for_extract_cards(image_dealer)
#       5 players,centers,points_f,labels = lib.players_clustering(extracted)
# ----> 6 cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)
#       7
#       8 for i in range(4):
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in find_corners(players, centers, image)
#     262         #print("right upper:",right_upper)
#     263
# --> 264         isolated = affin_transform(player,left_lower,right_lower,right_upper,image)
#     265         isolated_cards.append(isolated)
#     266
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in affin_transform(player, left_lower, right_lower, right_upper, image)
#     280         output_pts = np.float32([[cols,rows],[cols,0],[0,0]])
#     281
# --> 282     M= cv2.getAffineTransform(input_pts , output_pts)
#     283     res = cv2.warpAffine(image, M, (cols,rows))
#     284     return res
#
# UnboundLocalError: local variable 'output_pts' referenced before assignment

# %%
# total test:
file_list = lib.walkFile("../train_games")
for file in file_list:
    if file.endswith('.jpg'):
        print(file)
        show_suites_for_all_players(file)
# Out:
# ../train_games\game1\1.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  spade
# ../train_games\game1\10.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  club
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  heart
# ../train_games\game1\11.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  club
# player:  4
# matching suite:  diamond
# ../train_games\game1\12.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  heart
# ../train_games\game1\13.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  club
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  spade
# ../train_games\game1\2.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  club
# player:  4
# matching suite:  diamond
# ../train_games\game1\3.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  club
# player:  4
# matching suite:  diamond
# ../train_games\game1\4.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  club
# ../train_games\game1\5.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  club
# player:  4
# matching suite:  club
# ../train_games\game1\6.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  spade
# ../train_games\game1\7.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  heart
# ../train_games\game1\8.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  club
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  club
# ../train_games\game1\9.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  spade
# ../train_games\game2\1.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  diamond
# ../train_games\game2\10.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  club
# player:  4
# matching suite:  club
# ../train_games\game2\11.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  spade
# ../train_games\game2\12.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  diamond
# ../train_games\game2\13.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  spade
# ../train_games\game2\2.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  club
# player:  3
# matching suite:  club
# player:  4
# matching suite:  club
# ../train_games\game2\3.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  heart
# ../train_games\game2\4.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  club
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  club
# ../train_games\game2\5.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  club
# player:  4
# matching suite:  diamond
# ../train_games\game2\6.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  heart
# ../train_games\game2\7.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  club
# ../train_games\game2\8.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  diamond
# ../train_games\game2\9.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  club
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  diamond
# ../train_games\game3\1.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  spade
# ../train_games\game3\10.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  club
# ../train_games\game3\11.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  spade
# ../train_games\game3\12.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  heart
# ../train_games\game3\13.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  club
# ../train_games\game3\2.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  heart
# ../train_games\game3\3.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  diamond
# ../train_games\game3\4.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  diamond
# ../train_games\game3\5.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  club
# player:  4
# matching suite:  spade
# ../train_games\game3\6.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  club
# player:  3
# matching suite:  club
# player:  4
# matching suite:  diamond
# ../train_games\game3\7.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  club
# player:  4
# matching suite:  club
# ../train_games\game3\8.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  club
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  diamond
# ../train_games\game3\9.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  heart
# ../train_games\game4\1.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  club
# player:  4
# matching suite:  spade
# ../train_games\game4\10.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  club
# player:  4
# matching suite:  heart
# ../train_games\game4\11.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  heart
# ../train_games\game4\12.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  club
# ../train_games\game4\13.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  diamond
# ../train_games\game4\2.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  club
# player:  3
# matching suite:  club
# player:  4
# matching suite:  heart
# ../train_games\game4\3.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  spade
# ../train_games\game4\4.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  spade
# ../train_games\game4\5.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  club
# player:  4
# matching suite:  diamond
# ../train_games\game4\6.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  spade
# ../train_games\game4\7.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  diamond
# ../train_games\game4\8.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a2fb0e01b0f6> in <module>
#       4     if file.endswith('.jpg'):
#       5         print(file)
# ----> 6         show_suites_for_all_players(file)
#
# <ipython-input-7-b2e592fb004f> in show_suites_for_all_players(file)
#       5     extracted = lib.mask_for_extract_cards(image_dealer)
#       6     players,centers,points_f,labels = lib.players_clustering(extracted)
# ----> 7     cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)
#       8
#       9     for i in range(4):
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in find_corners(players, centers, image)
#     262         #print("right upper:",right_upper)
#     263
# --> 264         isolated = affin_transform(player,left_lower,right_lower,right_upper,image)
#     265         isolated_cards.append(isolated)
#     266
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in affin_transform(player, left_lower, right_lower, right_upper, image)
#     268
#     269 def affin_transform(player,left_lower,right_lower,right_upper,image):
# --> 270     input_pts = np.float32([left_lower,right_lower,right_upper])
#     271     cols=300
#     272     rows=400
#
# ValueError: setting an array element with a sequence.

# %%
# total test:
file_list = lib.walkFile("../train_games/game5")
for file in file_list:
    if file.endswith('.jpg'):
        print(file)
       
        show_suites_for_all_players(file)
# Out:
# ../train_games/game5\1.jpg
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  club
# player:  4
# matching suite:  club
# ../train_games/game5\10.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  club
# ../train_games/game5\11.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  club
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  club
# ../train_games/game5\12.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  heart
# ../train_games/game5\13.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  club
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  spade
# ../train_games/game5\2.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  heart
# ../train_games/game5\3.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  club
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  diamond
# ../train_games/game5\4.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  spade
# player:  3
# matching suite:  club
# player:  4
# matching suite:  spade
# ../train_games/game5\5.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  club
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  heart
# ../train_games/game5\6.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  spade
# ../train_games/game5\7.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  heart
# player:  3
# matching suite:  spade
# player:  4
# matching suite:  spade
# ../train_games/game5\8.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-ffac217b37f7> in <module>
#       5         print(file)
#       6         if file!='./train_games/game5\8.jpg':
# ----> 7             show_suites_for_all_players(file)
#
# <ipython-input-9-1aada2762580> in show_suites_for_all_players(file)
#       5     extracted = lib.mask_for_extract_cards(image_dealer)
#       6     players,centers,points_f,labels = lib.players_clustering(extracted)
# ----> 7     cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)
#       8
#       9     for i in range(4):
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in find_corners(players, centers, image)
#     262         #print("right upper:",right_upper)
#     263
# --> 264         isolated = affin_transform(player,left_lower,right_lower,right_upper,image)
#     265         isolated_cards.append(isolated)
#     266
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in affin_transform(player, left_lower, right_lower, right_upper, image)
#     268
#     269 def affin_transform(player,left_lower,right_lower,right_upper,image):
# --> 270     input_pts = np.float32([left_lower,right_lower,right_upper])
#     271     cols=300
#     272     rows=400
#
# ValueError: setting an array element with a sequence.

# %%
# total test:
file_list = lib.walkFile("../train_games/game6")
for file in file_list:
    if file.endswith('.jpg'):
        show_suites_for_all_players(file)
# Out:
# ../train_games/game6\1.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  spade
# player:  2
# matching suite:  club
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  spade
# ../train_games/game6\10.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  club
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  diamond
# ../train_games/game6\11.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  club
# player:  3
# matching suite:  club
# player:  4
# matching suite:  club
# ../train_games/game6\12.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  diamond
# player:  2
# matching suite:  diamond
# player:  3
# matching suite:  diamond
# player:  4
# matching suite:  spade
# ../train_games/game6\13.jpg
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-fec7a710bff5> in <module>
#       6         if file != '../train_games/game6\13.jpg':
#       7             print(file)
# ----> 8             show_suites_for_all_players(file)
#
# <ipython-input-9-1aada2762580> in show_suites_for_all_players(file)
#       5     extracted = lib.mask_for_extract_cards(image_dealer)
#       6     players,centers,points_f,labels = lib.players_clustering(extracted)
# ----> 7     cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)
#       8
#       9     for i in range(4):
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in find_corners(players, centers, image)
#     262         #print("right upper:",right_upper)
#     263
# --> 264         isolated = affin_transform(player,left_lower,right_lower,right_upper,image)
#     265         isolated_cards.append(isolated)
#     266
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in affin_transform(player, left_lower, right_lower, right_upper, image)
#     268
#     269 def affin_transform(player,left_lower,right_lower,right_upper,image):
# --> 270     input_pts = np.float32([left_lower,right_lower,right_upper])
#     271     cols=300
#     272     rows=400
#
# ValueError: setting an array element with a sequence.

# %%
file ='../train_games/game7/13.jpg'
show_suites_for_all_players(file)
# Out:
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# player:  1
# matching suite:  heart
# player:  2
# matching suite:  club
# player:  3
# matching suite:  heart
# player:  4
# matching suite:  heart

# %%
# total test:
file_list = lib.walkFile("../train_games/game7")
for file in file_list:
    if file.endswith('.jpg'):
        show_suites_for_all_players(file)
# Out:
# C:\Users\zyysu\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:984: RuntimeWarning: Explicit initial center position passed: performing only one init in KMeans instead of n_init=10.
#   self._check_params(X)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a number, not 'list'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-aa964c3a0419> in <module>
#       3 for file in file_list:
#       4     if file.endswith('.jpg'):
# ----> 5         show_suites_for_all_players(file)
#
# <ipython-input-3-1aada2762580> in show_suites_for_all_players(file)
#       5     extracted = lib.mask_for_extract_cards(image_dealer)
#       6     players,centers,points_f,labels = lib.players_clustering(extracted)
# ----> 7     cards,left_lowers,right_lowers,right_uppers = lib.find_corners(players,centers,image)
#       8
#       9     for i in range(4):
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in find_corners(players, centers, image)
#     262         #print("right upper:",right_upper)
#     263
# --> 264         isolated = affin_transform(player,left_lower,right_lower,right_upper,image)
#     265         isolated_cards.append(isolated)
#     266
#
# ~\OneDrive\Bureau\MA2\pattern\Image_analysis_project\yuan\lib.py in affin_transform(player, left_lower, right_lower, right_upper, image)
#     268
#     269 def affin_transform(player,left_lower,right_lower,right_upper,image):
# --> 270     input_pts = np.float32([left_lower,right_lower,right_upper])
#     271     cols=300
#     272     rows=400
#
# ValueError: setting an array element with a sequence.
